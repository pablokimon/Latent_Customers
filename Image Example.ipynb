# %% [markdown]
# ## Example of topic 1: The soup dimension
# ![topic0.png](attachment:topic0.png)![produce.gif](attachment:produce.gif)

# %% [markdown]
# ## Topic 2: The Salsa Dimension:
#
# ![topic2.png](attachment:topic2.png)![soup.gif](attachment:soup.gif)

# %% [markdown]
# ## Beyond Produce: The Bulk Nut and Dried Fruit Dimension:
#
# ![1554308215.topic0.png](attachment:1554308215.topic0.png)

# %% [markdown]
# ## Beyond Produce: The Bagel and Cream Cheese Dimesion:
# ![1554308216.topic1.png](attachment:1554308216.topic1.png)
